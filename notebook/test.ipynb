# %%
print("cloudy day")
# Out:
# cloudy day

# %%
from research_and_analyst.utils.model_loader import ModelLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from research_and_analyst.utils.model_loader import ModelLoader
#
# ModuleNotFoundError: No module named 'research_and_analyst'
